# %%
#Some sources I'm trying to follow
#https://www.youtube.com/watch?v=OdQ7xdXxeUA
#http://blog.appliedinformaticsinc.com/how-to-parse-and-convert-xml-to-csv-using-python/

#Step1: import lib

import csv
import xml.etree.cElementTree as ET
import os
import pandas as pd
import numpy as np

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/hfn/Documents/ipynb

# %%
#Step 2: Parse xml document and Get Root
root02 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2002.xml').getroot()
root03 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2003.xml').getroot()
root04 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2004.xml').getroot()
root05 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2005.xml').getroot()
root06 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2006.xml').getroot()
root07 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2007.xml').getroot()
root08 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2008.xml').getroot()
root09 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2009.xml').getroot()
root10 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2010.xml').getroot()
root11 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2011.xml').getroot()
root12 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2012.xml').getroot()
root13 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2013.xml').getroot()
root14 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2014.xml').getroot()
root15 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2015.xml').getroot()
root16 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2016.xml').getroot()
root17 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2017.xml').getroot()
root18 = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-2018.xml').getroot()
rootmod = ET.parse('/Users/hfn/Documents/nvdData/xml/nvdcve-2.0-modified.xml').getroot()

# %%
#Step 3: Create a dataframe
#http://gokhanatil.com/2017/11/python-for-data-science-importing-xml-to-pandas-dataframe.html
dfcols = ['cve', 'av', 'baseScore','ac','gdt']
df_xml02 = pd.DataFrame(columns=dfcols)
df_xml03 = pd.DataFrame(columns=dfcols)
df_xml04 = pd.DataFrame(columns=dfcols)
df_xml05 = pd.DataFrame(columns=dfcols)
df_xml06 = pd.DataFrame(columns=dfcols)
df_xml07 = pd.DataFrame(columns=dfcols)
df_xml08 = pd.DataFrame(columns=dfcols)
df_xml09 = pd.DataFrame(columns=dfcols)
df_xml10 = pd.DataFrame(columns=dfcols)
df_xml11 = pd.DataFrame(columns=dfcols)
df_xml12 = pd.DataFrame(columns=dfcols)
df_xml13 = pd.DataFrame(columns=dfcols)
df_xml14 = pd.DataFrame(columns=dfcols)
df_xml15 = pd.DataFrame(columns=dfcols)
df_xml16 = pd.DataFrame(columns=dfcols)
df_xml17 = pd.DataFrame(columns=dfcols)
df_xml18 = pd.DataFrame(columns=dfcols)
df_xmlmod = pd.DataFrame(columns=dfcols)

# %%
#Step 4: Define the namespace
cvss = {'cvss':'http://scap.nist.gov/schema/cvss-v2/0.2'}
namespace = {"namespace":"http://scap.nist.gov/schema/feed/vulnerability/2.0"}

# %%
#Step 5: Loop through to get data for each year, 2002
for entry in root02.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml02 = df_xml02.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2003
for entry in root03.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml03 = df_xml03.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2004
for entry in root04.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml04 = df_xml04.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2005
for entry in root05.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml05 = df_xml05.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2006
for entry in root06.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml06 = df_xml06.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2007
for entry in root07.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml07 = df_xml07.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2008
for entry in root08.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml08 = df_xml08.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2009
for entry in root09.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml09 = df_xml09.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2010
for entry in root10.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml10 = df_xml10.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2011
for entry in root11.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml11 = df_xml11.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2012
for entry in root12.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml12 = df_xml12.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2013
for entry in root13.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml13 = df_xml13.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2014
for entry in root14.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml14 = df_xml14.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2015
for entry in root15.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml15 = df_xml15.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2016
for entry in root16.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml16 = df_xml16.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2017
for entry in root17.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml17 = df_xml17.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#2018
for entry in root18.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text
    df_xml18 = df_xml18.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#md
#Not working
for entry in rootmod.findall('.//namespace:entry',namespace):
    entry_id = entry.get('id')
    for av in entry.findall('.//cvss:access-vector', cvss):
        av = av.text
    for score in entry.findall('.//cvss:score', cvss):
        score = score.text
    for auth in entry.findall('.//cvss:authentication', cvss):
        auth = auth.text
    for ac in entry.findall('.//cvss:access-complexity', cvss):
        ac = ac.text
    for gdt in entry.findall('.//cvss:generated-on-datetime', cvss):
        gdt = gdt.text 
    df_xmlmod = df_xmlmod.append(
        pd.Series([entry_id,av,score,ac,gdt], index=dfcols),ignore_index=True)

# %%
#Step 6: Concatenate the dfs
df_res = df_xml18.append(df_xml17)
df_res = df_res.append(df_xml16)
df_res = df_res.append(df_xml15)
df_res = df_res.append(df_xml14)
df_res = df_res.append(df_xml13)
df_res = df_res.append(df_xml12)
df_res = df_res.append(df_xml11)
df_res = df_res.append(df_xml10)
df_res = df_res.append(df_xml09)
df_res = df_res.append(df_xml08)
df_res = df_res.append(df_xml07)
df_res = df_res.append(df_xml06)
df_res = df_res.append(df_xml05)
df_res = df_res.append(df_xml04)
df_res = df_res.append(df_xml03)
df_res = df_res.append(df_xml02)
df_res = df_res.append(df_xmlmod)

# %%
df_res.describe()
# Out:
#                   cve       av baseScore      ac  \
# count          105158   105158    105158  105158
# unique         104349        3        73       3
# top     CVE-2014-7233  NETWORK       7.5     LOW
# freq                2    88950     16680   60340
#
#                                   gdt
# count                          105158
# unique                          88661
# top     2004-01-01T00:00:00.000-05:00
# freq                             7763

# %%
#Drop duplicates, but keep the last instance if a CVE
df_res = df_res.drop_duplicates(['cve'],keep='last')

# %%
df_res.describe()
# Out:
#                   cve       av baseScore      ac  \
# count          104349   104349    104349  104349
# unique         104349        3        73       3
# top     CVE-2006-0443  NETWORK       7.5     LOW
# freq                1    88306     16619   59897
#
#                                   gdt
# count                          104349
# unique                          88661
# top     2004-01-01T00:00:00.000-05:00
# freq                             7763

# %%
#Sort on cve
df_res = df_res.sort_values('cve', axis=0, ascending=False)

# %%
#Step 7: Create a csv
df_res.to_csv('/Users/hfn/Documents/nvdData/csv/df_res_1.2.csv', sep=',', index=False)
